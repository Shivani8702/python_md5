# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivani8702/python_md5/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import hashlib
text="Think and wonder, wonder and think."
hash_object = hashlib.md5(text.encode())
md5_hash = hash_object.hexdigest()

print(md5_hash)
# Out:
# e21bf3fe43a5974d726935f5c63f3b13
